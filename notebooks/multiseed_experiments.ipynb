# %%
# !git clone https://github.com/frankmeyo1738-creator/Federated-Learning-Simulator-for-Low-Connectivity-Environments.git
# %cd Federated-Learning-Simulator-for-Low-Connectivity-Environments

# %%
# !pip install torch torchvision pyyaml pandas matplotlib seaborn numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.makedirs('/content/drive/MyDrive/FL_Simulator_Results/multiseed', exist_ok=True)

# %%
# !bash scripts/run_multiseed_experiments.sh

# %%
# !cp -r experiments/results/multiseed/* /content/drive/MyDrive/FL_Simulator_Results/multiseed/
print("✅ Results saved to Google Drive!")

# %%
# !ls experiments/results/multiseed/ | wc -l
print("CSV files generated:")
# !ls experiments/results/multiseed/*.csv
